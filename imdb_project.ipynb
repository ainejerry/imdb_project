# %%
import pandas as pd

# %%
#basics data set link
basics_link="https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
#read the data set into pandas
df_basics=pd.read_csv(basics_link, sep='\t',low_memory= False)

# %%
#a .head() of the basics data sets 
df_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
#replacing "\N" with "np.nan" in our basics data set 
df_basics.replace({'\\N':'np.nan'},inplace= True)
df_basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894  np.nan              1         Documentary,Short
# 1       0      1892  np.nan              5           Animation,Short
# 2       0      1892  np.nan              4  Animation,Comedy,Romance
# 3       0      1892  np.nan             12           Animation,Short
# 4       0      1893  np.nan              1              Comedy,Short

# %%
#variable to match the movies in the akas dataset with the movies in the basics data set
keepers =df_basics['tconst'].isin(df_akas['titleId'])
keepers
# Out:
# 0            True
# 1            True
# 2           False
# 3           False
# 4            True
#             ...
# 10261069    False
# 10261070    False
# 10261071    False
# 10261072    False
# 10261073    False
# Name: tconst, Length: 10261074, dtype: bool

# %%
#passing the variable in the basics data set 
df_basics = df_basics[keepers]
df_basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10260935  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10260964  tt9916620     movie                            The Copeland Case
# 10261002  tt9916702     short                Loving London: The Playground
# 10261025  tt9916756     short                     Pretty Pretty Black Girl
# 10261029  tt9916764     short                                           38
#
# ...

# %%
#deleting all movies that have null values in the runtime column
df_basics= df_basics[~df_basics['runtimeMinutes'].str.contains('np.nan')]
df_basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10260767  tt9916214     short                              Drown the Clown
# 10260787  tt9916254     video                         Big Tit Cream Pie 32
# 10260833  tt9916348     video                        Ancient World Exposed
# 10260840  tt9916362     movie                                        Coven
# 10260935  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
#
# ...

# %%
#deleting movies with the null values in the genre column 
df_basics= df_basics[~df_basics['genres'].str.contains('np.nan')]
df_basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10260767  tt9916214     short                              Drown the Clown
# 10260787  tt9916254     video                         Big Tit Cream Pie 32
# 10260833  tt9916348     video                        Ancient World Exposed
# 10260840  tt9916362     movie                                        Coven
# 10260935  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
#
# ...

# %%
#value_counts of the title type column
df_basics['titleType'].value_counts()
# Out:
# titleType
# short           278752
# movie           204162
# tvEpisode       174020
# video           115778
# tvSeries         36854
# tvMovie          25970
# tvSpecial         9342
# tvMiniSeries      6028
# tvShort           4113
# videoGame          197
# Name: count, dtype: int64

# %%
#keeping movies that have 'movie' in the titletype type column 
df_basics= df_basics[df_basics['titleType'].str.contains('movie')]
df_basics
# Out:
#              tconst titleType                    primaryTitle  \
# 8         tt0000009     movie                      Miss Jerry
# 144       tt0000147     movie   The Corbett-Fitzsimmons Fight
# 570       tt0000574     movie     The Story of the Kelly Gang
# 587       tt0000591     movie                The Prodigal Son
# 672       tt0000679     movie  The Fairylogue and Radio-Plays
# ...             ...       ...                             ...
# 10260429  tt9915436     movie               Vida em Movimento
# 10260607  tt9915872     movie            The Last White Witch
# 10260747  tt9916170     movie                   The Rehearsal
# 10260756  tt9916190     movie                       Safeguard
# 10260840  tt9916362     movie                           Coven
#
#                            originalTitle isAdult startYear endYear  \
# 8                             Miss Jerry       0      1894  np.nan
# 144        The Corbett-Fitzsimmons Fight       0      1897  np.nan
# ...

# %%
#confirming the change has been effected 
df_basics['titleType'].value_counts()
# Out:
# titleType
# movie    204162
# Name: count, dtype: int64

# %%
#changing startYear to a NUMERIC COLUMN 
df_basics['startYear'] = pd.to_numeric(df_basics['startYear'],errors='coerce')
df_basics['startYear'].value_counts()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23688\2707654086.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_basics['startYear'] = pd.to_numeric(df_basics['startYear'],errors='coerce')
# startYear
# 2019.0    8103
# 2018.0    7864
# 2017.0    7810
# 2016.0    7409
# 2015.0    7232
#           ...
# 1906.0       2
# 1899.0       1
# 1904.0       1
# 1897.0       1
# 1894.0       1
# Name: count, Length: 128, dtype: int64

# %%
#changing the data type of the startYear column to be a float 
df_basics['startYear'] = df_basics['startYear'].astype(float)
df_basics['startYear'].value_counts()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23688\1091404853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_basics['startYear'] = df_basics['startYear'].astype(float)
# startYear
# 2019.0    8103
# 2018.0    7864
# 2017.0    7810
# 2016.0    7409
# 2015.0    7232
#           ...
# 1906.0       2
# 1899.0       1
# 1904.0       1
# 1897.0       1
# 1894.0       1
# Name: count, Length: 128, dtype: int64

# %%
#filtering out movies with a start year between 2000 and 2021
df_basics=df_basics[(df_basics['startYear']>=2000)&(df_basics['startYear']<=2021)]

# %%
#confirming the change 
df_basics['startYear'].value_counts()
# Out:
# startYear
# 2019.0    8103
# 2018.0    7864
# 2017.0    7810
# 2016.0    7409
# 2015.0    7232
# 2014.0    7171
# 2020.0    7031
# 2013.0    6947
# 2021.0    6925
# 2012.0    6595
# 2011.0    6122
# 2010.0    5586
# 2009.0    5085
# 2008.0    4244
# 2007.0    3608
# 2006.0    3342
# 2005.0    2924
# 2004.0    2535
# 2003.0    2194
# 2002.0    2003
# 2001.0    1932
# 2000.0    1789
# Name: count, dtype: int64

# %%
#deleting all movies that have documentary as a genre 
df_basics= df_basics[~df_basics['genres'].str.contains('Documentary')]
df_basics
# Out:
#              tconst titleType  \
# 34800     tt0035423     movie
# 61111     tt0062336     movie
# 67485     tt0068865     movie
# 67663     tt0069049     movie
# 86790     tt0088751     movie
# ...             ...       ...
# 10260213  tt9914942     movie
# 10260607  tt9915872     movie
# 10260747  tt9916170     movie
# 10260756  tt9916190     movie
# 10260840  tt9916362     movie
#
#                                                primaryTitle  \
# 34800                                        Kate & Leopold
# 61111     The Tango of the Widower and Its Distorting Mi...
# 67485                                   Lives of Performers
# 67663                            The Other Side of the Wind
# 86790                                     The Naked Monster
# ...                                                     ...
# 10260213                             Life Without Sara Amat
# 10260607                               The Last White Witch
# ...

# %%
#to get final info about our basics data set 
df_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 81902 entries, 34800 to 10260840
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81902 non-null  object
#  1   titleType       81902 non-null  object
#  2   primaryTitle    81901 non-null  object
#  3   originalTitle   81901 non-null  object
#  4   isAdult         81902 non-null  object
#  5   startYear       81902 non-null  float64
#  6   endYear         81902 non-null  object
#  7   runtimeMinutes  81902 non-null  object
#  8   genres          81902 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.2+ MB

# %%
#saving the filtered data frame 
df_basics.to_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\basics_data.csv.gz",compression='gzip',index=False)

# %%
#loading the saved data frame into pandas 
basics = pd.read_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\basics_data.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear endYear  \
# 0                             Kate & Leopold        0     2001.0  np.nan
# 1  El tango del viudo y su espejo deformante        0     2020.0  np.nan
# 2                        Lives of Performers        0     2016.0  np.nan
# 3                 The Other Side of the Wind        0     2018.0  np.nan
# 4                          The Naked Monster        0     2005.0  np.nan
#
#    runtimeMinutes                  genres
# ...

# %%
#reading the akas data set into pandas 
df_akas = pd.read_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\title-akas-us-only.csv",low_memory=False)
df_akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
#replacing "\N" with "np.nan" in our akas data set
df_akas.replace({'\\N':'np.nan'},inplace= True)

# %%
#confirming the change 
df_akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US   np.nan  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US   np.nan       np.nan
# 2  tt0000005        10        Blacksmith Scene     US   np.nan  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US   np.nan  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US   np.nan  alternative
#
#               attributes isOriginalTitle
# 0                 np.nan               0
# 1  literal English title               0
# 2                 np.nan               0
# 3                 np.nan               0
# 4                 np.nan               0

# %%
#final info about our akas data set 
df_akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452564 entries, 0 to 1452563
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1452564 non-null  object
#  1   ordering         1452564 non-null  int64
#  2   title            1452562 non-null  object
#  3   region           1452564 non-null  object
#  4   language         1452564 non-null  object
#  5   types            1452564 non-null  object
#  6   attributes       1452564 non-null  object
#  7   isOriginalTitle  1452564 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 88.7+ MB

# %%
df_akas
# Out:
#            titleId  ordering                                      title  \
# 0        tt0000001         6                                 Carmencita
# 1        tt0000002         7                     The Clown and His Dogs
# 2        tt0000005        10                           Blacksmith Scene
# 3        tt0000005         1                        Blacksmithing Scene
# 4        tt0000005         6                        Blacksmith Scene #1
# ...            ...       ...                                        ...
# 1452559  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 1452560  tt9916620         1                          The Copeland Case
# 1452561  tt9916702         1              Loving London: The Playground
# 1452562  tt9916756         1                   Pretty Pretty Black Girl
# 1452563  tt9916764         1                                         38
#
#         region language        types             attributes isOriginalTitle
# ...

# %%
#saving the data frame
df_akas.to_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\akas-us-only.csv.gz",compression='gzip',index = False)

# %%
#reading the saved data frame into pandas 
us_only=pd.read_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\akas-us-only.csv.gz", low_memory = False)

# %%
#a .head() of the saved data frame 
us_only.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US   np.nan  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US   np.nan       np.nan
# 2  tt0000005        10        Blacksmith Scene     US   np.nan  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US   np.nan  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US   np.nan  alternative
#
#               attributes isOriginalTitle
# 0                 np.nan               0
# 1  literal English title               0
# 2                 np.nan               0
# 3                 np.nan               0
# 4                 np.nan               0

# %%
#a link to the rates data set 
rates_link="https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
#reading the rating data set into pandas with the link from the previous cell
df_rates=pd.read_csv(rates_link, sep='\t',low_memory= False)

# %%
df_rates.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2003
# 1  tt0000002            5.8       269
# 2  tt0000003            6.5      1896
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2681

# %%
#variable to match the movies in the akas dataset with the movies in the ratings data set
keeper =df_rates['tconst'].isin(df_akas['titleId'])
keeper
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1361914    False
# 1361915    False
# 1361916    False
# 1361917    False
# 1361918    False
# Name: tconst, Length: 1361919, dtype: bool

# %%
#passing that variable into the rates dat set 
df_rates = df_rates[keeper]
df_rates
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23688\4243409111.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df_rates = df_rates[keeper]
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      2003
# 1        tt0000002            5.8       269
# 4        tt0000005            6.2      2681
# 5        tt0000006            5.0       183
# 6        tt0000007            5.4       839
# ...            ...            ...       ...
# 1361577  tt9909228            6.7        39
# 1361631  tt9910522            3.4         5
# 1361807  tt9914192            5.3       296
# 1361815  tt9914414            6.0        16
# 1361822  tt9914598            6.1        94
#
# [161624 rows x 3 columns]

# %%
#replacing "\N" with "np.nan" in our rates data set
df_rates.replace({'\\N':'np.nan'},inplace= True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_23688\285920261.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rates.replace({'\\N':'np.nan'},inplace= True)

# %%
#final info about the rates data set 
df_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161624 entries, 0 to 1361822
# Data columns (total 3 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   tconst         161624 non-null  object
#  1   averageRating  161624 non-null  float64
#  2   numVotes       161624 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.9+ MB

# %%
#saving the editted data frame 
df_rates.to_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\ratings_data.csv.gz",compression='gzip',index = False)

# %%
#loading the editted data frame into pandas 
rates = pd.read_csv(r"C:\Users\DELL\Documents\GitHub\imdb_project\Data\ratings_data.csv.gz", low_memory = False)
rates.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2003
# 1  tt0000002            5.8       269
# 2  tt0000005            6.2      2681
# 3  tt0000006            5.0       183
# 4  tt0000007            5.4       839
